# %% [markdown]
# <a href="https://colab.research.google.com/github/AREEBA-art552/iris-flower-classification/blob/main/unemployment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📊 Socioeconomic Indicators Visualization from Uploaded ZIP File

import zipfile
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Upload ZIP
from google.colab import files
uploaded = files.upload()  # Upload your 'archive .zip.zip'

# Get ZIP filename automatically
zip_filename = list(uploaded.keys())[0]

# Extract
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall(".")

# Auto-detect CSV
csv_file = None
for file in os.listdir():
    if file.endswith(".csv"):
        csv_file = file
        print(f"✅ Found CSV file: {csv_file}")
        break

# Load Data
df = pd.read_csv(csv_file)
print("✅ Data loaded successfully!")

# Preview
display(df.head())
print(df.info())

# === 📈 VISUALIZATIONS === #

sns.set(style="whitegrid")

# 1. Unemployment Rate Over Years
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='Year', y='Unemployment Rate (%)', marker='o')
plt.title('Unemployment Rate Over the Years')
plt.ylabel('Unemployment Rate (%)')
plt.xlabel('Year')
plt.grid(True)
plt.tight_layout()
plt.show()

# 2. Government Social Spending Over the Years
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Year', y='Government Social Spending (% of GDP)', color='skyblue')
plt.title('Government Social Spending Over the Years')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Climate Disasters Per Year
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='Year', y='Climate Disasters (count)', marker='o', color='red')
plt.title('Climate Disasters Per Year')
plt.ylabel('Disaster Count')
plt.grid(True)
plt.tight_layout()
plt.show()

# 4. Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
plt.title("Correlation Matrix of Socioeconomic Indicators")
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-da934371-9b2a-4ab5-b057-b659a4b4f0d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da934371-9b2a-4ab5-b057-b659a4b4f0d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
